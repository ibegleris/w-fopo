# %% [markdown]
# # Assigment for arthur
# This pdf was created in the notebook to show that you can use latex with python easily here.
#
# $$
# E = m c^{2}
# $$

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def arthur_notebook():
    return 'Use the damn notebook'
x = np.linspace(0,2*np.pi)

# %%
fig = plt.figure()
plt.plot(x, np.sin(x))
plt.title(arthur_notebook())
plt.show()

# %% [markdown]
# # Conclusion
#
# I conclude that the notebook is awesome!
